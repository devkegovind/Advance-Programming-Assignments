# %% [markdown]
# ---
# <h1 align='center'><b>ADVANCE PYTHON ASSIGNMENT NO.19</b></h1>
#
#
# ---

# %% [markdown]
# <h4 align='justify'><b>Q1. Define the relationship between a class and its instances. Is it a one-to-one or a one-to-many partnership, for example?</b></h4>
# <h4 align='justify'> Class is abstraction of an real world entity. It consist of attributes and methods. Instance is an object of a class. It one to many relationship between class and its instatnces.</h4>

# %% [markdown]
# <h4 align='justify'><b>Q2. What kind of data is held only in an instance?</b></h4>
# <h4 align='justify'>Instance objects contains the Instance variables which are specific Instance object.</h4>

# %% [markdown]
# <h4 align='justify'><b>Q3. What kind of knowledge is stored in a class?</b></h4>
# <h4 align='justify'><b>Class creates a user-defined data structure, which holds its own data members and member functions, which can be accessed and used by creating an instance of that class. A class is like a blueprint for an object.</h4>

# %% [markdown]
# <h4 align='justify'><b>Q4. What exactly is a method, and how is it different from a regular function?</b></h4>
# <h4 align='justify'>The methods with a class can be used to access the instance variables of it's instance. So, the object's state can be modified by its method. Function cant access the attributes of an instance of a class or cant modify the state of the object.</h4>

# %% [markdown]
# <h4 align='justify'><b>Q5. Is inheritance supported in Python, and if so, what is the syntax?</b></h4>
# <h4 align='justify'>Inheritance is supported by python</h4>

# %%
class A:
  var = 1
  def __init__(self):
    pass

class B(A): # class B is derived from class A
  def __init__(self):
    super().__init__()

c = B()
print(f"Class of Instance {c.__class__}")
print(f"Base class {c.__class__.__bases__}")
# Out:
# Class of Instance <class '__main__.B'>
# Base class (<class '__main__.A'>,)

# %% [markdown]
# <h4 align='justify'><b>Q6. How much encapsulation (making instance or class variables private) does Python support?</b></h4>
# <h4 align='justify'>Encapsulation prevents from accessing accidentally, but not initionality. The private attributes and methods are not really hidden. The private can be accessed within the object method.</h4>

# %% [markdown]
# <h4 align='justify'><b>Q7. How do you distinguish between a class variable and an instance variable?</b></h4>
# <h4 align='justify'>The class attribute is available to all the instance objects of that class. Instance variable is accessible only to the object or Instance of that class.</h4>

# %% [markdown]
# <h4 align='justify'><b>Q8. When, if ever, can self be included in a class&#39;s method definitions?</b></h4>
# <h4 align='justify'>self can included to access the class variables and instance variables.</h4>

# %% [markdown]
# <h4 align='justify'><b>Q9. What is the difference between the _ _add_ _ and the _ _radd_ _ methods?</b></h4>
# <h4 align='justify'>When you add two numbers using the + operator, internally, the __add__() method will be called. We can overload this method to perform.</h4>

# %% [markdown]
# <h4 align='justify'><b>Q10. When is it necessary to use a reflection method? When do you not need it, even though you support the operation in question?</b></h4>
# <h4 align='justify'>Suppose we are implementing a class that you want to act like a number via operator overloading. So we implement</h4>
#
# -  __add__ in your class, and now expressions like obj + 10 is acceptable. This is because obj + 10 is interpreted
#
# - as obj.__add__(10), and the custom method __add__ can do whatever it means to add 10 to custom class.
#
# - However, what about an expression like 10 + obj which is really (10).__add__(myobj)?
#
# - The 10 is an instance of a python built-in type and its __add__ method doesn't know anything about the new type, obj, so it will return an error NotImplemented.
#
# - To handle such scenerio, __radd__ is used. Python will first try (10).__add__(myobj), and if that returns NotImplemented, python will check if the right-hand operand implements __radd__, and if it does, it will call obj.__radd__(10) rather than raising a TypeError.

# %% [markdown]
# <h4 align='justify'><b>Q11. What is the _ _iadd_ _ method called?</b></h4>\
# <h4 align='justify'>__iadd__method is called when we use implementation like a+= b which is a.__add__(b)</h4>

# %%
class A:
  def __init__(self, x):
    self.x = x
  
  def __iadd__(self, other):
    self.x += other.x
    return self.x 

obj1 = A(2)
obj2 = A(3)
obj1 += obj2
print(obj1)
# Out:
# 5

# %% [markdown]
# <h4 align='justify'><b>Q12. Is the _ _init_ _ method inherited by subclasses? What do you do if you need to customize its behavior within a subclass?</b></h4>
# <h4 align='justify'>__init__ method is inherited by its subclass. But it can be overloaded, to customize it</h4>
# # Ans : __init__ method is inherited by its subclass. But it can be overloaded, to customize it
# class A:
#     def __init__(self,x):
#         self.x=x
# class B(A):
#     pass
# obj=B(2)
# obj.x
# #        here the value x is accessible to instance of class B which is subclass of class A.This means
# #        __init__ of class A is inherited in sub class B
# class C(A):
#     def __init__(self,x,y): # Here we are overloading the __init__ inherited from class A
#         self.x=x
#         self.y=y
#     def func(self):
#         return(self.x + self.y)
# obj1=C(3,4)
# obj1.func()

# %%
class A:
  def __init__(self, x):
    self.x = x

class B(A):
  pass

obj = B(2)
obj.x # here the value x is accessible to instance of class B which is 
# subclass of class A. 
# __init__ of class A is inherited in sub class B 

class C(A):
  def __init__(self, x, y): # Here we are overloading the __init__ inherited from class A
    self.x = x
    self.y = y

  def func(self):
    return(self.x + self.y)

obj1 = C(3,4)
obj1.func()
# Out:
# 7
