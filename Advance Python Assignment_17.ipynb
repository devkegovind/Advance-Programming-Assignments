# %% [markdown]
# ---
# <h1 align='center'><b>ADVANCE PYTHON ASSIGNMENT NO.17</b>
# </h1>
#
# ---

# %% [markdown]
# <h4 align = 'justify'><b>Q1. Explain the difference between greedy and non-greedy syntax with visual terms in as few words
# as possible. What is the bare minimum effort required to transform a greedy pattern into a non-greedy one? What characters or characters can you introduce or change?</b></h4>
# <h4 align = 'justify'>Greedy version, Python matches the longest possible string</h4>

# %%
import re
text = " "
greedyregobj = re.compile(r'<.*>')
match = greedyregobj.search(text)
print(match.group())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-37277160ab8e> in <module>
#       3 greedyregobj = re.compile(r'<.*>')
#       4 match = greedyregobj.search(text)
# ----> 5 print(match.group())
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %% [markdown]
# <h4 align = 'justify'>The Non-Greedy version of the regex, Python matches the shortage string.</h4>

# %%
nongreedyregobj = re.compile(r'')
match1 = nongreedyregobj.search(text)
match1.group()
# Out:
# ''

# %% [markdown]
# <h4 align = 'justify'><b>
# Q2. When exactly does greedy versus non-greedy make a difference?  What if you&#39;re looking for a
# non-greedy match but the only one available is greedy?</b></h4>
# <h4 align = 'justify'>In the non-greedy version of the regex, Python matches the shortest possible string. In the greedy version, Python matches the longest possible string. If only non greedy match is available, we can use other filtering or pattern matching methods of regex and further identify the required pattern.</h4>

# %% [markdown]
# <h4 align = 'justify'><b>
# Q3. In a simple match of a string, which looks only for one match and does not do any replacement, is
# the use of a nontagged group likely to make any practical difference?</b></h4>

# %%
import re
phoneNumRegex = re.compile(r'\d\d\d')
mo = phoneNumRegex.search("My number is 415-555-4242")
print('Phone number found: ' + mo.group()) # non tagged group
print("Phone number found: " + mo.group(0))
# Out:
# Phone number found: 415
# Phone number found: 415

# %% [markdown]
# <h4 align = 'justify'><b>
# Q4. Describe a scenario in which using a nontagged category would have a significant impact on the
# program&#39;s outcomes.</b></h4>

# %%
# Non tagged category
import re
text = '135-135'
pattern = r'(\d+)(?:.)(\d+)'
regobj = re.compile(pattern)
matchobj = regobj.search(text)
matchobj.groups()

# Here the '.' decimal is not tagged or captured
# It will useful in scenarios where the seperator of value in a string is of no 
# use and we need to capture only the values

# %% [markdown]
# <h4 align = 'justify'><b>
# Q5. Unlike a normal regex pattern, a look-ahead condition does not consume the characters it
# examines. Describe a situation in which this could make a difference in the results of your
# programme.</b></h4>
# <h4 align = 'justify'>While counting the number of multiple lines or multiple sentences in a string the positive look ahead make a difference, without which we want get the correct count of lines or sentences in a string.</h4>

# %% [markdown]
# <h4 align = 'justify'><b>
# Q6. In standard expressions, what is the difference between positive look-ahead and negative look-
# ahead?</b></h4>
# <h4 align = 'justify'>Positive look ahead is an assertion continuing the search and extending the string e.g. pattern r'abc(?=[A-Z])' Here after 'abc', ? is extending the search and says that in the remaining string, first identify the next.</h4>
# <h4 align = 'justify'>Example:</h4>

# %%
import re
pat = r'abc(?=[A-Z])'
text = "abcABCEF"
regobj = re.compile(pat)
matchobj = regobj.findall(text)
print(f"Positive Lookahead {matchobj}")

# Negative look head is also an assertion to exclude certain patterns.
# e.g. pattern = r'abc(?!abc)', means identify a substring containing
# 'abc' which is not followed by another 'abc'
# Example of Neagtive Lookahead

import re
pat1 = r'abc(?!abc)'
text1 = "aeiouabcabc"
regobj1 = re.compile(pat1)
matchobj1 = regobj1.findall(text)
print(f"Negative Look Ahead {matchobj1}")
# Out:
# Positive Lookahead ['abc']
# Negative Look Ahead ['abc']

# %% [markdown]
# <h4 align = 'justify'><b>
# Q7. What is the benefit of referring to groups by name rather than by number in a standard expression?</b></h4>
# <h4 align = 'justify'>The benefits of referring to the groups by name is that</h4>
#
# *   The code is clear
# *   It is easier to maintain the code.

# %% [markdown]
# <h4 align = 'justify'><b>
# Q8. Can you identify repeated items within a target string using named groups, as in &quot;The cow
# jumped over the moon&quot;?</b></h4>

# %%
import re
text = "The cow jumped over the moon"
regobj = re.compile(r'(The)', re.I)
regobj.findall(text)
# Out:
# ['The', 'the']

# %% [markdown]
# <h4 align = 'justify'><b>
# Q9. When parsing a string, what is at least one thing that the Scanner interface does for you that the re.findall feature does not?</b></h4>
# <h4 align = 'justify'>re.search() method either returns None(if the pattern doesn't match), or a re.MatchObject that contains information about the matching part of the string. This method stops after the first match, so this is best suited for testing a regular expression more than extracting data, whereas Return all non-overlapping matches of pattern in string, as a list of strings. The string is scanned left to right, and matches are returned in the order found.</h4>

# %% [markdown]
# <h4 align = 'justify'><b>
# Q10. Does a scanner object have to be named scanner?</b></h4>
# <h4 align = 'justify'>The scanner object need not be named scanner. It may have any name.</h4>
